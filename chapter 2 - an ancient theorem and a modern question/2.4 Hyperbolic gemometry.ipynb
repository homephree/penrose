# %%
from math import sin, cos, tan, acosh, pi, tanh, sinh, cosh, atanh
from poincare import HyperbolicLine, HyperbolicPoint
from poincare.poincaredisk import PoincareDiskModel
import matplotlib.pyplot as plot
import numpy as np
from bokeh.io import output_notebook
from bokeh.plotting import show

# %% [markdown]
# Summary of circular and hyperbolic functions

# %%
X= [x for x in range(314)] # (approx pi in hundredths)
S= [sin(x * np.pi /100 ) for x in X]
C= [cos(x * np.pi /100 ) for x in X]
plot.plot(S,C)

# %% [markdown]
# whereas the sine and cosine functions define the coordinate of a circle, for x in the range 1..pi

# %%
plot.show()

# %%
X= [x for x in range(20)]
S= [sinh(x/100) for x in X]
C= [cosh(x/100) for x in X]
plot.plot(S,C)

# %% [markdown]
# hyperbolic variants sinh and cosh map a hyperbolic curve

# %%
plot.show()

# %%
X= [x for x in range(10)]
T= [tanh(x) for x in X]
plot.plot(X,T)
plot.show()

# %% [markdown]
# draw some lines on a poincare disk (hyperbolic plane)
#
# In geometry, the Poincaré disk model also called the conformal disk model, is a model of 2-dimensional hyperbolic geometry in which the points of the geometry are inside the unit disk, and the straight lines consist of all segments of circles contained within that disk that are orthogonal to the boundary of the disk, plus all diameters of the disk.
#
# https://en.wikipedia.org/wiki/Poincaré_disk_model

# %% [markdown]
# draw some squares of various sizes, after defining hyp poly functions

# %%
pdm= PoincareDiskModel();

def hyp_poly(euclid_couples, major_radius_length=1):
    return[HyperbolicPoint( x/major_radius_length, y/major_radius_length) \
                     for x,y in euclid_couples]

def draw_hyp_poly(pdm, poly, major_radius_length= 1):
    hpoly= hyp_poly(poly, major_radius_length=major_radius_length)
    lines= [HyperbolicLine(hpoly[i], hpoly[i+1]) \
            for i in range( -1, len(hpoly)-1)]
    for l in lines:
          pdm.drawline( l)  

def move_x( quadrilateral, dx):
    return map( lambda p : (p[0]+dx, p[1]), quadrilateral)

def move_y( quadrilateral, dy):
    return map( lambda p : (p[0], p[1]+dy), quadrilateral)

right_quadrilateral= [ (-1,-1), (-1,1), (1,1), (1,-1)]

for dx in range ( -6,7,2):
    for dy in range ( -6,7,2):
        draw_hyp_poly( pdm, move_y( move_x( right_quadrilateral,dx),dy), major_radius_length= 10)

big= 9.9
draw_hyp_poly(pdm, [(-big,0),(0,big),(big,0),(0,-big)], major_radius_length= 10)

# %%
output_notebook()
pdm.show()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f3363ca7-2edd-4c9b-a8e3-cf4d954f0146">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d74916aa-69d7-4f3f-ae93-89eccd543614"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d74916aa-69d7-4f3f-ae93-89eccd543614").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d74916aa-69d7-4f3f-ae93-89eccd543614");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd74916aa-69d7-4f3f-ae93-89eccd543614' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"253b11bd-ce4e-4ef3-aa64-63c3056654ca":{"roots":{"references":[{"attributes":{"end_angle":{"units":"rad","value":1.6775319994440319},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.938675189355249},"start_angle":{"units":"rad","value":1.4640606541457608},"x":{"value":0.5999999999999996},"y":{"value":-1.233333333333334}},"id":"a037142d-11f5-4988-b420-de2e48b2c91a","type":"Arc"},{"attributes":{"end_angle":{"units":"rad","value":1.735945004209523},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.608276253029822},"start_angle":{"units":"rad","value":1.4056476493802694},"x":{"value":0.3999999999999998},"y":{"value":-1.1}},"id":"941fe711-7e17-4aa5-ab3a-79288e6460f7","type":"Arc"},{"attributes":{"callback":null},"id":"69ab94ea-b1df-4433-a49d-232536ce9f1b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2425c2f4-4e4f-42f5-b3d6-42e25efe0305","type":"ColumnDataSource"},"glyph":{"id":"44a15cf1-23fc-4131-b03a-1f013d996e78","type":"Arc"},"hover_glyph":null,"nonselection_glyph":{"id":"38c7fc18-0d18-440b-918c-309b3c1c6348","type":"Arc"},"selection_glyph":null},"id":"3d2d4f9a-bc26-44e3-b78e-123168460440","type":"GlyphRenderer"},{"attributes":{"end_angle":{"units":"rad","value":0.020830320036217084},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":4.801041553663122},"start_angle":{"units":"rad","value":6.262354987143369},"x":{"value":-4.9},"y":{"value":-0.2}},"id":"e8807add-a230-4106-b54e-9da6c942669c","type":"Arc"},{"attributes":{"data_source":{"id":"c6edccd3-97fa-44e4-8072-8b3001ff6e3a","type":"ColumnDataSource"},"glyph":{"id":"b7c5526f-eaf6-40e1-94ac-d4cc3f2e45fc","type":"Arc"},"hover_glyph":null,"nonselection_glyph":{"id":"89ecc3f8-a58e-4482-902f-40c5f91e9cce","type":"Arc"},"selection_glyph":null},"id":"8023c409-a5ea-4503-8462-d723948c4725","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a02ca818-234c-4fd5-9ad0-c336335f2c2b","type":"ColumnDataSource"},"glyph":{"id":"d4171cb8-b55a-4e99-af4c-1a6695a79e7c","type":"Arc"},"hover_glyph":null,"nonselection_glyph":{"id":"a7b220c7-4803-4b19-a24f-688ed215e529","type":"Arc"},"selection_glyph":null},"id":"dd75a80e-a4a2-4945-8021-efc8b24fd707","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"2cb31e4a-8cfb-4045-95d1-711e76015705","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"24b53c46-0651-419d-aca6-71655958856c","type":"ColumnDataSource"},{"attributes":{"end_angle":{"units":"rad","value":2.289626326416521},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.1518592258962091},"start_angle":{"units":"rad","value":0.8519663271732735},"x":{"value":-0.5999999999999999},"y":{"value":-0.8142857142857144}},"id":"89ecc3f8-a58e-4482-902f-40c5f91e9cce","type":"Arc"},{"attributes":{"end_angle":{"units":"rad","value":0.3708912888126624},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.27590297022611404},"start_angle":{"units":"rad","value":5.912294018366924},"x":{"value":-0.9571428571428573},"y":{"value":0.3999999999999999}},"id":"d19eb59f-c6e9-415f-8d5c-664561a4c92e","type":"Arc"},{"attributes":{"callback":null},"id":"80226e18-608d-4365-a8e3-aaf9d4c6d1c5","type":"ColumnDataSource"},{"attributes":{"callback":null,"start":-1},"id":"57e1a59e-7055-4db7-99d3-1e511c62c412","type":"Range1d"},{"attributes":{"callback":null},"id":"1a840051-038a-4440-9fda-363ef1a164d4","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"9e9bee7b-f18e-44e3-9c59-98a945b55d71","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"f9ed1217-c548-4436-900d-fdb7aea18c43","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"1eae7cbf-6d8a-41d4-bb73-510be2fe3f10","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"5b3a7c2f-9d1d-4c94-94c1-64cc97d9d81f","type":"BasicTickFormatter"},"plot":{"id":"b535527b-b7d9-45f4-af63-9aabe9221b7c","subtype":"Figure","t ...

# %% [markdown]
# The grid isn't projecting onto the shpere but using cartesian points mapped to hyperbolic lines.

# %%
pdm= PoincareDiskModel();

def arcpoint(frm,to):
    return ( HyperbolicPoint(sin(frm)*.9999, cos(frm)*.9999), \
                                HyperbolicPoint(sin(to)*.9999, cos(to)*.9999))

def cornerarc( pdm, frm, to):
    frm= pi*frm/180
    to= pi*to/180
    arc= arcpoint(frm,to)
    pdm.drawline(HyperbolicLine( arc[0], arc[1]))
    
for steps in range( 2, 12):
    for x in range( 0, 360 ,  int(360 / steps)):
        cornerarc(pdm, x, x + int(360 / steps))



pdm.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a3349d7e-c062-444c-ba50-dab268171e66"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a3349d7e-c062-444c-ba50-dab268171e66").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a3349d7e-c062-444c-ba50-dab268171e66");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a3349d7e-c062-444c-ba50-dab268171e66' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2502f5e9-e6be-47a5-a242-93b809963179":{"roots":{"references":[{"attributes":{"callback":null},"id":"62e836c7-1931-442d-8559-75f9ab732fbb","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"26d2944b-4fc8-4b97-b908-88fe9d6a76a6","type":"ColumnDataSource"},{"attributes":{"end_angle":{"units":"rad","value":1.0470243374573194},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5773502807377863},"start_angle":{"units":"rad","value":5.236160969722268},"x":{"value":-1.1547005441533318},"y":{"value":-4.441336232123834e-16}},"id":"51b6e351-882e-4fa9-9211-bb8d12c36120","type":"Arc"},{"attributes":{"end_angle":{"units":"rad","value":3.141492648590127},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":1.000000010001},"start_angle":{"units":"rad","value":1.5708963317945632},"x":{"value":1.0000000050005},"y":{"value":-1.0000000050005}},"id":"598c37e5-949a-42b7-b3f4-aa80a2085fa7","type":"Arc"},{"attributes":{"callback":null},"id":"c21c5634-aeaa-4973-9e89-b5fdaad78351","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"86f73e7e-b0ce-430c-a625-5485d73e8e42","type":"ColumnDataSource"},{"attributes":{"end_angle":{"units":"rad","value":5.863957527833631},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.28674540463149356},"start_angle":{"units":"rad","value":3.2815677526166556},"x":{"value":0.14478169913984637},"y":{"value":1.0301753184150055}},"id":"a7fef603-eac7-4439-9086-4e1dd40428a8","type":"Arc"},{"attributes":{"callback":null},"id":"c01c2d30-c0f0-4f30-8a08-fa291f91ac65","type":"ColumnDataSource"},{"attributes":{"end_angle":{"units":"rad","value":2.0942218886539172},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5773502807377859},"start_angle":{"units":"rad","value":0.00017321373927887498},"x":{"value":-0.5773502720766656},"y":{"value":-1.0000000050005002}},"id":"07459514-cf9e-4a81-b09d-35d932e283e2","type":"Arc"},{"attributes":{"end_angle":{"units":"rad","value":5.724331187674085},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.28674540463149356},"start_angle":{"units":"rad","value":3.141941412457109},"x":{"value":0.28674538719267817},"y":{"value":1.0000000050005}},"id":"58f4badf-a645-40d1-a3e1-7feedda8b793","type":"Arc"},{"attributes":{"formatter":{"id":"e59e62c9-480e-4e93-8640-5c5ce11593eb","type":"BasicTickFormatter"},"plot":{"id":"ea0a4ba6-4d52-4381-a9f5-11ceb1ab99f9","subtype":"Figure","type":"Plot"},"ticker":{"id":"cd332dd1-ce0a-46e6-99f1-b9f298500454","type":"BasicTicker"}},"id":"d012f3b7-cc72-4aa5-815c-f102ebd049bf","type":"LinearAxis"},{"attributes":{"end_angle":{"units":"rad","value":6.283047662106499},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.7265425385210347},"start_angle":{"units":"rad","value":4.398367360098797},"x":{"value":-0.7265425316384371},"y":{"value":1.0000000050004998}},"id":"e4346788-51a3-49c4-bdf3-2f81290b8469","type":"Arc"},{"attributes":{"data_source":{"id":"403be42f-5979-44f8-88fc-66edc3971fd9","type":"ColumnDataSource"},"glyph":{"id":"0b19febf-c556-43ac-9e9d-2d6bfb4ebfc5","type":"Arc"},"hover_glyph":null,"nonselection_glyph":{"id":"fef70e00-1088-4b1e-90ff-e540ba668c1b","type":"Arc"},"selection_glyph":null},"id":"02b9ddf0-cf38-4bbb-a263-b6ae457bbcd3","type":"GlyphRenderer"},{"attributes":{},"id":"e4df9bcb-d656-4b7f-91e8-2a5b0eacd1d3","type":"ToolEvents"},{"attributes":{"data_source":{"id":"238efd59-3746-4ffe-a127-b93721a0e9c1","type":"ColumnDataSource"},"glyph":{"id":"90e85465-fab5-43a6-ad1f-3a90ff83e02c","type":"Arc"},"hover_glyph":null,"nonselection_glyph":{"id":"ce7fae65-79bd-409c-8ec7-148c09507779","type":"Arc"},"selection_glyph":null},"id":"2d467a4f-4cba-45de-af48-99ecdb5e8aed","type":"GlyphRenderer"},{"attributes":{"end_angle":{"units":"rad","value":0.697782941930417},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.2867454046314932},"st ...

# %% [markdown]
# draw the triangle in fig 2.12

# %%
pdm= PoincareDiskModel();

triangle= [(0.3,0),(0.7,-.4),(0.1,-0.3)]
draw_hyp_poly(pdm, triangle)

cornerarc(pdm, -10,-100)
cornerarc(pdm, 10,-80)

HyperbolicPoint(.5,0).hyperbolic_circle( 0.4)
pdm.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="61e0d9c4-d135-4b5c-abff-22cbc41afafe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("61e0d9c4-d135-4b5c-abff-22cbc41afafe").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("61e0d9c4-d135-4b5c-abff-22cbc41afafe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '61e0d9c4-d135-4b5c-abff-22cbc41afafe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d2b4a8e7-d377-4a8d-a310-10c4edea5374":{"roots":{"references":[{"attributes":{"end_angle":{"units":"rad","value":1.6125215983600125},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":1.480700526251986},"start_angle":{"units":"rad","value":1.1987737004005266},"x":{"value":0.16176470588235262},"y":{"value":-1.7794117647058827}},"id":"74bcf922-7b3c-47f1-bd96-1f7567215422","type":"Arc"},{"attributes":{"end_angle":{"units":"rad","value":6.283185307179586},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":1.0},"start_angle":{"units":"rad","value":0.0},"x":{"value":0.0},"y":{"value":0.0}},"id":"d8f0eb5b-2e42-4d30-8a21-aa457dfc8839","type":"Arc"},{"attributes":{"data_source":{"id":"5f125a2b-152e-4828-8b6d-e14acdc57145","type":"ColumnDataSource"},"glyph":{"id":"afa0940f-d396-461a-99c6-10e9c89315fe","type":"Arc"},"hover_glyph":null,"nonselection_glyph":{"id":"ab1e46ef-3edc-4abb-aedf-58367c3412cc","type":"Arc"},"selection_glyph":null},"id":"e2c77d42-2b8a-46e4-b3fe-5233b5f5e534","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2e6c2244-d18e-42a0-8390-ab254fae2a87","subtype":"Figure","type":"Plot"}},"id":"91d7ae10-fb49-4b4c-a73b-e4b35539bca5","type":"ZoomOutTool"},{"attributes":{"callback":null},"id":"5f125a2b-152e-4828-8b6d-e14acdc57145","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"0ba9df1d-3e5e-46ef-b789-44f93021e922","type":"LinearAxis"}],"left":[{"id":"f39bac9c-7a05-41e0-8129-452a4e18333e","type":"LinearAxis"}],"min_border":50,"renderers":[{"id":"0ba9df1d-3e5e-46ef-b789-44f93021e922","type":"LinearAxis"},{"id":"facd6ab2-0ab6-4778-9fb3-e6b9959c3aed","type":"Grid"},{"id":"f39bac9c-7a05-41e0-8129-452a4e18333e","type":"LinearAxis"},{"id":"46fcfa27-5edd-44f8-91ac-3ecbdc912d88","type":"Grid"},{"id":"cec23062-df12-4f04-8a25-8c1269f859ce","type":"GlyphRenderer"},{"id":"bd34a843-f476-404b-a054-daff1cb0b1a6","type":"GlyphRenderer"},{"id":"e2c77d42-2b8a-46e4-b3fe-5233b5f5e534","type":"GlyphRenderer"},{"id":"50de0748-b47c-4441-ac00-8c590c6c57da","type":"GlyphRenderer"},{"id":"2c53d3d4-8c0a-45f3-8b4f-4f14f9959f2d","type":"GlyphRenderer"},{"id":"6f3bfb60-f053-4e27-872c-7fd840a3381c","type":"GlyphRenderer"}],"title":{"id":"ae2a4a3d-9ef8-4d5a-abe4-0c6954867ac9","type":"Title"},"tool_events":{"id":"efc97caf-de6c-49df-bd6e-faa77162df11","type":"ToolEvents"},"toolbar":{"id":"f671d44a-d240-41d6-8bf3-3f6e6dfff124","type":"Toolbar"},"x_range":{"id":"e13d8bc8-07b7-434e-b21e-a9f3e1ee10be","type":"Range1d"},"y_range":{"id":"beefe9eb-f42d-48ee-998e-bfe697f843b0","type":"Range1d"}},"id":"2e6c2244-d18e-42a0-8390-ab254fae2a87","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"2e6c2244-d18e-42a0-8390-ab254fae2a87","subtype":"Figure","type":"Plot"},"ticker":{"id":"66c12902-0ddb-4574-8b9f-cf61ccdb3057","type":"BasicTicker"}},"id":"facd6ab2-0ab6-4778-9fb3-e6b9959c3aed","type":"Grid"},{"attributes":{},"id":"783b0c58-ce35-4b3d-a5ba-adbfa7b705a2","type":"BasicTickFormatter"},{"attributes":{"end_angle":{"units":"rad","value":6.108552376980486},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":1.000000010001},"start_angle":{"units":"rad","value":4.537956060184923},"x":{"value":-0.8111595794014812},"y":{"value":1.1584559364719973}},"id":"4cedc281-7dcf-42d9-a0b0-4431efe10fe8","type":"Arc"},{"attributes":{"end_angle":{"units":"rad","value":4.077737198107663},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":1.88340707820222},"start_angle":{"units":"rad","value":3.7762444358668197},"x":{"value":1.8166666666666669},"y":{"value":1.116666666666667}},"id":"afa0940f-d396-461a-99c6-10e9c89315fe","type":"Arc"},{"attributes":{"data_source":{"id":"14de6c48-194e-454c-8924-9891caf9fe93","type":"ColumnDataSource"},"glyph":{"id":"4cedc281-7dcf-42d9-a0b0-4431efe10fe8","type":"Arc"},"hover_glyph":null,"nonselection_glyph":{"id":"d18940ac-e939-4e1f-a51b-627a5f4cbef9","type":"Arc"},"selection_glyph":null},"id":"6f3bfb60-f053-4e27-872c-7fd840a3381 ...

# %%
htriangle= hpoly(triangle)
a= HyperbolicPoint.angle_between_three_points(htriangle[0], htriangle[1], htriangle[2])
b= HyperbolicPoint.angle_between_three_points(htriangle[1], htriangle[2], htriangle[0])
c= HyperbolicPoint.angle_between_three_points(htriangle[2], htriangle[0], htriangle[1])
(a,b,c, ("C_times_area", pi-(a+b+c)))
# Out:
# (0.6173437267576599,
#  1.1471394359981273,
#  1.3730985120593329,
#  ('C_times_area', 0.004010978774672935))

# %%
htriangle[0].distance(htriangle[1])
# Out:
# 0.11349676834939007
